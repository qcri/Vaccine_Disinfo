# %% [markdown]
# ### Sep

# %%
import pandas as pd
import json
from collections import defaultdict as ddict
from datetime import date

# %%
domains_vt1 = '/bad_ip_data/ucsc/Vaccine_Disinfo/data/covid_resources/dataset_sep_2020/oxford-vaccine-article_urls-shared-on-twitter.csv.1.scan.report'
domains_vt2 = '/bad_ip_data/ucsc/Vaccine_Disinfo/data/covid_resources/dataset_sep_2020/oxford-vaccine-article_urls-shared-on-twitter.csv.2.scan.report'

# %%
domains_vt = [i.split('\n')[0] for i in open(domains_vt1,'r').readlines()]+[i.split('\n')[0] for i in open(domains_vt2,'r').readlines()]

# %%
def timeduration(d0,d1):
    d0y,d0m,d0d =  list(map(int,d0.split(' ')[0].split('-')))
    d1y,d1m,d1d =  list(map(int,d1.split(' ')[0].split('-')))
    return date(d1y,d1m,d1d)-date(d0y,d0m,d0d)

# %%
import tldextract
VT = ddict(list)
for i in domains_vt:
    try:
        tmp = json.loads(i)
        url = tldextract.extract(tmp.get('url'))
        VT['domain'].append('{}.{}'.format(url.domain,url.suffix))
        VT['url'].append(tmp.get('url'))
        VT['total'].append(tmp.get('total'))
        VT['positives'].append(tmp.get('positives'))
        VT['duration[VT]'].append(timeduration(tmp.get('first_seen'),tmp.get('last_seen')))
        
        try:
            rlength = tmp.get('additional_info').get('rlength')
            if rlength != None : VT['rlength'].append(rlength)
            if rlength == None : VT['rlength'].append(None)
        except AttributeError:
            VT['rlength'].append(None)
        
        try:
            resolution = tmp.get('additional_info').get('resolution')
            if resolution != None : VT['resolution'].append(resolution)
            if resolution == None : VT['resolution'].append(None)
        except AttributeError:
            VT['resolution'].append(None)
            
        try:    
            server = tmp.get('additional_info').get('Response headers').get('server')
            if server != None: VT['server'].append(server)
            if server == None: VT['server'].append(None)
        except AttributeError:
            VT['server'].append(None)
        
        try:
            URLAfterRredirects = tmp.get('additional_info').get('URL after redirects')
            if URLAfterRredirects != None: 
                VT['URL after redirects'].append(URLAfterRredirects)
                VT['Final URL'].append(URLAfterRredirects)
            if URLAfterRredirects == None:
                VT['URL after redirects'].append('None')
                VT['Final URL'].append(tmp.get('url'))
        except AttributeError:
            VT['URL after redirects'].append(None)
            VT['Final URL'].append(tmp.get('url'))
            
    except ValueError:
        pass
VT = pd.DataFrame(VT)

# %%
VT.loc[VT.positives==1]
# Out:
#            domain                                                url  total  \
# 64        cutt.ly                            https://cutt.ly/4fzBosk     83
# 75        lnkd.in   https://lnkd.in/ebK-ScW%20https:/lnkd.in/eSxeNiA     83
# 95          ow.ly                           http://ow.ly/qWYO30r7DIV     83
# 138        bit.ly                             https://bit.ly/2GcaKKm     83
# 152    mailchi.mp  https://mailchi.mp/3fa3cde81895/dialoguemos-12...     83
# ...           ...                                                ...    ...
# 14497     cutt.ly                            https://cutt.ly/tfT3H3K     83
# 14501     cutt.ly                            https://cutt.ly/XfT2E6a     83
# 14663      owl.li                          http://owl.li/dFwu30r98IR     83
# 14702     cutt.ly                            https://cutt.ly/jfT7NnN     83
# 14731      bit.ly                             https://bit.ly/2RdpQl6     83
#
#        positives duration[VT]   rlength     resolution             server  \
# 64             1       0 days  205455.0   104.22.1.232  Sucuri/Cloudproxy
# 75             1      98 days   38385.0  108.174.10.10               None
# 95             1       0 days     196.0   54.67.120.65             Apache
# 138            1       0 days       NaN  67.199.248.10               None
# 152            1       0 days  109738.0  72.246.201.73          openresty
# ...          ...          ...       ...            ...                ...
# 14497          1      98 days  135330.0   172.67.8.238             Apache
# 14501          1       0 days   20925.0   104.22.1.232             Apache
# 14663          1       0 days   65866.0   54.67.62.204         cloudflare
# 14702          1      98 days   44020.0   104.22.0.232         cloudflare
# 14731          1       0 days   34100.0  67.199.248.10             Apache
#
#                                      URL after redirects  \
# 64     https://gmnoticias.mx/segundo-voluntario-de-va...
# 75     https://www.linkedin.com/feed/update/urn:li:sh...
# 95     https://www.informaoriente.com.mx/salud/comien...
# 138                                                 None
# 152                                                 None
# ...                                                  ...
# 14497  https://eldiariodecoahuila.com.mx/2020/09/10/i...
# 14501  https://www.olivanoticias.com/mundo/137344/vac...
# 14663  http://purmamarcadiariodigital.com.ar/contenid...
# 14702  https://contraparte.mx/internacionales/41442-v...
# 14731  https://consensodelmercado.com/bolsas-internac...
#
#                                                Final URL
# 64     https://gmnoticias.mx/segundo-voluntario-de-va...
# 75     https://www.linkedin.com/feed/update/urn:li:sh...
# 95     https://www.informaoriente.com.mx/salud/comien...
# 138                               https://bit.ly/2GcaKKm
# 152    https://mailchi.mp/3fa3cde81895/dialoguemos-12...
# ...                                                  ...
# 14497  https://eldiariodecoahuila.com.mx/2020/09/10/i...
# 14501  https://www.olivanoticias.com/mundo/137344/vac...
# 14663  http://purmamarcadiariodigital.com.ar/contenid...
# 14702  https://contraparte.mx/internacionales/41442-v...
# 14731  https://consensodelmercado.com/bolsas-internac...
#
# [274 rows x 10 columns]

# %%
VT[['url','URL after redirects','Final URL']]
# Out:
#                                                      url  \
# 0      https://forbes.com.br/negocios/2020/06/astraze...
# 1      https://www.google.com/amp/s/www.elespanol.com...
# 2                                   http://xhne.ws/yXuub
# 3      https://www.nbcnews.com/health/health-news/lar...
# 4      https://mol.im/a/8684869%20http:/dailym.ai/and...
# ...                                                  ...
# 14831  https://indianexpress.com/article/india/oxford...
# 14832  https://launica945.com/category/meche-castro-e...
# 14833  https://twitter.com/SMadlokovu/status/13021590...
# 14834                             https://cnb.cx/3hjLheQ
# 14835  https://twitter.com/surianna/status/1303976690...
#
#                                      URL after redirects  \
# 0                                                   None
# 1      https://www.elespanol.com/invertia/observatori...
# 2      http://www.xinhuanet.com/english/2020-09/02/c_...
# 3                                                   None
# 4                                                   None
# ...                                                  ...
# 14831                                               None
# 14832  https://www.launica945.com/category/meche-cast...
# 14833  https://mobile.twitter.com/SMadlokovu/status/1...
# 14834  https://www.cnbc.com/2020/09/10/who-calls-dela...
# 14835  https://mobile.twitter.com/surianna/status/130...
#
#                                                Final URL
# 0      https://forbes.com.br/negocios/2020/06/astraze...
# 1      https://www.elespanol.com/invertia/observatori...
# 2      http://www.xinhuanet.com/english/2020-09/02/c_...
# 3      https://www.nbcnews.com/health/health-news/lar...
# 4      https://mol.im/a/8684869%20http:/dailym.ai/and...
# ...                                                  ...
# 14831  https://indianexpress.com/article/india/oxford...
# 14832  https://www.launica945.com/category/meche-cast...
# 14833  https://mobile.twitter.com/SMadlokovu/status/1...
# 14834  https://www.cnbc.com/2020/09/10/who-calls-dela...
# 14835  https://mobile.twitter.com/surianna/status/130...
#
# [14836 rows x 3 columns]
