# %%
import pandas as pd
import json
from tqdm.notebook import tqdm

# %%
adns  = [i.split('\n')[0] for i in open('/bad_ip_data/ucsc/Vaccine_Disinfo/data/mal_fqdns.csv.adns','r').readlines()]

# %%
adns
# Out:
# ['d3ag4hukkh62yn.cloudfront.net. 29 IN A 13.35.176.39',
#  'www.amazon.com. canonicalname d3ag4hukkh62yn.cloudfront.net.',
#  'www.amazon.com. qname www.amazon.com.',
#  'www.amazon.com. expiration 1610536329.9698417',
#  'www.amazon.com. rdclass 1',
#  'www.amazon.com. rdtype 1',
#  'l-0005.dc-msedge.net. 191 IN A 13.107.43.14',
#  'www.linkedin.com. canonicalname l-0005.dc-msedge.net.',
#  'www.linkedin.com. qname www.linkedin.com.',
#  'www.linkedin.com. expiration 1610536466.7539725',
#  'www.linkedin.com. rdclass 1',
#  'www.linkedin.com. rdtype 1',
#  'tatar-congress.org. 299 IN A 185.75.47.6',
#  'tatar-congress.org. canonicalname tatar-congress.org.',
#  'tatar-congress.org. qname tatar-congress.org.',
#  'tatar-congress.org. expiration 1610536600.3089123',
#  'tatar-congress.org. rdclass 1',
#  'tatar-congress.org. rdtype 1',
#  'tatar-congress.org. MX mx.yandex.ru.:10',
#  'tatar-congress.org. NS 10 mx.yandex.ru.',
#  'arsitios.com. 300 IN A 172.67.177.187',
# ...

# %%
i=0
cycle=0
while i<len(adns):
    if i!=len(adns) and adns[i].split()[0]==adns[i+1].split()[0]:
        data = adns[i].split()
        if 'A' in data:
        if 'qname' in data:
        if 'expiration' in data:
        if 'canonicalname' in data:
        if 'MX' in data:
        if 'NS' in data:
        break
    i+=1
# Out:
# www.amazon.com.

# %%
adns[0].split()
# Out:
# ['d3ag4hukkh62yn.cloudfront.net.', '29', 'IN', 'A', '13.35.176.39']
